# %% [markdown]
# # Imports

# %%
import pandas as pd
import yfinance as yf
import numpy as np

# %%
events_df = pd.read_csv("events_pct_changes.csv")

# %%
events_df.columns
events_df
# Out:
#             date symbol        when  \
# 0     2023-01-03   LEDS   premarket
# 1     2023-01-03    SGH  postmarket
# 2     2023-01-04    RGP  postmarket
# 3     2023-01-04    SLP  postmarket
# 4     2023-01-05    CAG   premarket
# ...          ...    ...         ...
# 8445  2023-12-21   CTAS   premarket
# 8446  2023-12-21    KMX   premarket
# 8447  2023-12-21   LMNR  postmarket
# 8448  2023-12-21    NKE   premarket
# 8449  2023-12-21   PAYX   premarket
#
#                                       security_name exchange_codes  \
# 0               SemiLEDS Corporation - Common Stock         NASDAQ
# 1     SMART Global Holdings, Inc. - Ordinary Shares         NASDAQ
# 2         Resources Connection, Inc. - Common Stock         NASDAQ
# 3             Simulations Plus, Inc. - Common Stock         NASDAQ
# 4                 ConAgra Brands, Inc. Common Stock           XNYS
# ...                                             ...            ...
# 8445              Cintas Corporation - Common Stock         NASDAQ
# 8446                                     CarMax Inc           XNYS
# 8447                    Limoneira Co - Common Stock         NASDAQ
# 8448                        Nike, Inc. Common Stock           XNYS
# 8449                   Paychex, Inc. - Common Stock         NASDAQ
#
#      before_eps_date after_eps_date Ticker        Date   Adj Close  ...  \
# 0         2022-12-30     2023-01-03   LEDS  2023-01-03    1.820000  ...
# 1         2023-01-03     2023-01-04    SGH  2023-01-04   15.750000  ...
# 2         2023-01-04     2023-01-05    RGP  2023-01-05   14.715991  ...
# 3         2023-01-04     2023-01-05    SLP  2023-01-05   34.700558  ...
# 4         2023-01-04     2023-01-05    CAG  2023-01-05   37.901043  ...
# ...              ...            ...    ...         ...         ...  ...
# 8445      2023-12-20     2023-12-21   CTAS  2023-12-21  588.635681  ...
# 8446      2023-12-20     2023-12-21    KMX  2023-12-21   78.550003  ...
# 8447      2023-12-21     2023-12-22   LMNR  2023-12-22   20.435904  ...
# 8448      2023-12-20     2023-12-21    NKE  2023-12-21  122.093781  ...
# 8449      2023-12-20     2023-12-21   PAYX  2023-12-21  118.039871  ...
#
#             High         Low        Open      Volume  Adj Close_pct_change  \
# 0       2.090000    1.750000    2.090000     84200.0              0.137500
# 1      17.094999   15.570000   16.870001   1791600.0              0.041667
# 2      17.879999   15.380000   17.879999    774000.0             -0.171858
# 3      37.939999   32.580002   35.349998    587900.0             -0.070954
# 4      40.779999   39.049999   39.660000   8498400.0              0.034153
# ...          ...         ...         ...         ...                   ...
# 8445  591.260010  568.710022  577.000000    670600.0              0.065546
# 8446   84.199997   77.230003   84.199997   7568000.0              0.051821
# 8447   20.980000   19.469999   20.000000    172900.0              0.068786
# 8448  123.300003  121.300003  122.300003  16533300.0              0.009059
# 8449  122.250000  118.589996  122.250000   5820000.0             -0.070077
#
#       Close_pct_change  High_pct_change  Low_pct_change  Open_pct_change  \
# 0             0.137500         0.306250        0.166667         0.306250
# 1             0.041667         0.098650        0.042169         0.121676
# 2            -0.171858        -0.045891       -0.167749        -0.042314
# 3            -0.070954        -0.008623       -0.118029        -0.044853
# 4             0.034153         0.048599        0.018253         0.022165
# ...                ...              ...             ...              ...
# 8445          0.065546         0.050009        0.027387         0.031481
# 8446          0.051821         0.091098        0.035116         0.108770
# 8447          0.068786         0.089870        0.038400         0.048218
# 8448          0.009059        -0.000729        0.002479         0.009659
# 8449         -0.070077        -0.057149       -0.071921        -0.046635
#
#       Volume_pct_change
# 0              1.209974
# 1              0.550229
# 2              3.892541
# 3              1.637506
# 4              0.575967
# ...                 ...
# 8445           0.284674
# 8446           0.981930
# 8447           1.584454
# 8448           0.801680
# 8449           1.107550
#
# [8450 rows x 21 columns]

# %%
# drop unecessary columns
events_df = events_df[['date', 'symbol','security_name', 
       'before_eps_date', 'after_eps_date', 'Adj Close',
       'Close',  'Adj Close_pct_change',
       'Close_pct_change']].copy()

# %%
events_df
# Out:
#             date symbol                                  security_name  \
# 0     2023-01-03   LEDS            SemiLEDS Corporation - Common Stock
# 1     2023-01-03    SGH  SMART Global Holdings, Inc. - Ordinary Shares
# 2     2023-01-04    RGP      Resources Connection, Inc. - Common Stock
# 3     2023-01-04    SLP          Simulations Plus, Inc. - Common Stock
# 4     2023-01-05    CAG              ConAgra Brands, Inc. Common Stock
# ...          ...    ...                                            ...
# 8445  2023-12-21   CTAS              Cintas Corporation - Common Stock
# 8446  2023-12-21    KMX                                     CarMax Inc
# 8447  2023-12-21   LMNR                    Limoneira Co - Common Stock
# 8448  2023-12-21    NKE                        Nike, Inc. Common Stock
# 8449  2023-12-21   PAYX                   Paychex, Inc. - Common Stock
#
#      before_eps_date after_eps_date   Adj Close       Close  \
# 0         2022-12-30     2023-01-03    1.820000    1.820000
# 1         2023-01-03     2023-01-04   15.750000   15.750000
# 2         2023-01-04     2023-01-05   14.715991   15.420000
# 3         2023-01-04     2023-01-05   34.700558   34.959999
# 4         2023-01-04     2023-01-05   37.901043   39.970001
# ...              ...            ...         ...         ...
# 8445      2023-12-20     2023-12-21  588.635681  589.950012
# 8446      2023-12-20     2023-12-21   78.550003   78.550003
# 8447      2023-12-21     2023-12-22   20.435904   20.510000
# 8448      2023-12-20     2023-12-21  122.093781  122.529999
# 8449      2023-12-20     2023-12-21  118.039871  118.900002
#
#       Adj Close_pct_change  Close_pct_change
# 0                 0.137500          0.137500
# 1                 0.041667          0.041667
# 2                -0.171858         -0.171858
# 3                -0.070954         -0.070954
# 4                 0.034153          0.034153
# ...                    ...               ...
# 8445              0.065546          0.065546
# 8446              0.051821          0.051821
# 8447              0.068786          0.068786
# 8448              0.009059          0.009059
# 8449             -0.070077         -0.070077
#
# [8450 rows x 9 columns]

# %%
result_eps = pd.DataFrame()
def get_basic_eps(row):  
    result = pd.DataFrame()
    result = pd.DataFrame(columns = ['Earnings Date', 'ticker', "EPS Estimate", "Reported EPS", "Surprise(%)"])
    print(row)
    return result
    try:
        ticker_data = yf.Ticker(row)
        eps_data  = ticker_data.get_earnings_dates(limit=12)
        # income_stmt = ticker_data.income_stmt.T["Basic EPS"]
        result = pd.DataFrame(eps_data).reset_index()
        result['ticker'] = row
        result = result[['Earnings Date', 'ticker', "EPS Estimate", "Reported EPS", "Surprise(%)"]].copy()
        result.dropna(inplace = True)
        pd.concat(result_eps, result)
        return result
        
    except Exception as e:
        print(f'Error:{e}')
        return np.nan

# %% [markdown]
# # Check Tickers
#
# confirm that yfinance has ticker earnings data available

# %%
unique_tickers = pd.DataFrame(events_df['symbol'].unique(), columns = ['ticker'])

# %%
unique_tickers
# Out:
#      ticker
# 0      LEDS
# 1       SGH
# 2       RGP
# 3       SLP
# 4       CAG
# ...     ...
# 2358   TRAK
# 2359   BERY
# 2360    POL
# 2361   SDRL
# 2362    MNR
#
# [2363 rows x 1 columns]

# %%
unique_tickers_test = unique_tickers.iloc[:20, :].copy()
unique_tickers_test
# Out:
#    ticker
# 0    LEDS
# 1     SGH
# 2     RGP
# 3     SLP
# 4     CAG
# 5    HELE
# 6     LNN
# 7      LW
# 8     MSM
# 9     RPM
# 10   APLD
# 11    AYI
# 12    AZZ
# 13   PSMT
# 14   VOXX
# 15    ACI
# 16    OGI
# 17    BAC
# 18     BK
# 19    BLK

# %%
def check_ticker(row):
    """for each ticker, get earnings data if no earnings data found for the stock, return the error and the symbol"""
    errors_list = [] # to keep track of what happened to each stock
    result = pd.DataFrame()
    try:
        ticker_data = yf.Ticker(row)
        eps_data  = ticker_data.get_earnings_dates(limit=12).reset_index()
        eps_data['Symbol'] = row # add a column with the symbol into the DF (to concat later)
        # summary_list.append({'Symbol': row, 'Errors': 'Earnings Data found'})
        result = eps_data
    except Exception as e:
        result = {'Symbol': row, 'Errors': f"{e}"}
    res_dict = [result, errors_list]
    return result

# %%
import timeit

start_time = timeit.default_timer()

# get earnings data for each ticker: 
tuple = unique_tickers['ticker'].apply(check_ticker)

## Time:
elapsed_seconds = timeit.default_timer() - start_time
elapsed_minutes = elapsed_seconds / 60
print(f"Time taken: {elapsed} seconds")
print(f"Time taken: {elapsed_minutes} minutes")
# Out:
# SCSC: No earnings dates found, symbol may be delisted
# QRTEA: No earnings dates found, symbol may be delisted
# GRND: No earnings dates found, symbol may be delisted
# MOVE: No earnings dates found, symbol may be delisted
# NWS: No earnings dates found, symbol may be delisted
# PSQH: No earnings dates found, symbol may be delisted
# BETR: No earnings dates found, symbol may be delisted
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 11
#       9 elapsed_seconds = timeit.default_timer() - start_time
#      10 elapsed_minutes = elapsed_seconds / 60
# ---> 11 print(f"Time taken: {elapsed} seconds")
#      12 print(f"Time taken: {elapsed_minutes} minutes")
#
# NameError: name 'elapsed' is not defined

# %%
print(type(tuple))
print(len(tuple))
print(tuple)
# Out:
# <class 'pandas.core.series.Series'>
# 2363
# 0                      Earnings Date  EPS Estimate  Re...
# 1                      Earnings Date  EPS Estimate  Re...
# 2                      Earnings Date  EPS Estimate  Re...
# 3                      Earnings Date  EPS Estimate  Re...
# 4                      Earnings Date  EPS Estimate  Re...
#                               ...
# 2358                  Earnings Date  EPS Estimate  Rep...
# 2359                   Earnings Date  EPS Estimate  Re...
# 2360                   Earnings Date  EPS Estimate  Re...
# 2361                   Earnings Date  EPS Estimate  Re...
# 2362                   Earnings Date  EPS Estimate  Re...
# Name: ticker, Length: 2363, dtype: object

# %%
tuple
# Out:
# 0                    Earnings Date  EPS Estimate  Re...
# 1                    Earnings Date  EPS Estimate  Re...
# 2                    Earnings Date  EPS Estimate  Re...
# 3                    Earnings Date  EPS Estimate  Re...
# 4                    Earnings Date  EPS Estimate  Re...
# 5                    Earnings Date  EPS Estimate  Re...
# 6                    Earnings Date  EPS Estimate  Re...
# 7                    Earnings Date  EPS Estimate  Re...
# 8                    Earnings Date  EPS Estimate  Re...
# 9                    Earnings Date  EPS Estimate  Re...
# 10                   Earnings Date  EPS Estimate  Re...
# 11                   Earnings Date  EPS Estimate  Re...
# 12                   Earnings Date  EPS Estimate  Re...
# 13                   Earnings Date  EPS Estimate  Re...
# 14                   Earnings Date  EPS Estimate  Re...
# 15                   Earnings Date  EPS Estimate  Re...
# 16                   Earnings Date  EPS Estimate  Re...
# 17                   Earnings Date  EPS Estimate  Re...
# 18                   Earnings Date  EPS Estimate  Re...
# 19                   Earnings Date  EPS Estimate  Re...
# Name: ticker, dtype: object

# %%
final_df = pd.DataFrame()
for index in range(len(tuple)):
    item = tuple[index]
    # print(item)
    result_df = []
    error_df_test = pd.DataFrame()
    if isinstance(item, pd.DataFrame):
        final_df = pd.concat([final_df,item])
    elif isinstance(item, dict):
        print('found dict:')
        print(item)
        # error_df_test = pd.DataFrame(item, index = [index])
        # errors_df = pd.concat([error_df_test,tuple[index]])
    else:
        print("Unknown type")
# print(error_df_test)
print(final_df)
# Out:
# found dict:
# {'Symbol': 'MTCH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NEU', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'OI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'OSK', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PHM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PII', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PNR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'POWL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PSX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'RNR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SNAP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SPOT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ST', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SYK', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'WDC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AFG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AFL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ALGN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ALGT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ARAY', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ATKR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AVNW', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AVT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ENSG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FLWS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GEN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GILD', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GOOS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GPRO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GTIM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HBI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HOG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HON', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HSY', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HUBG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ITI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ITW', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'JHG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LANC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LAZ', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LEA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LPLA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LQDT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LSPD', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LVWR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'POWI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'RMBS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SKY', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SPG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SRDX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SSD', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SWKS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'TFII', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'TKR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'TSN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'TTWO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'UDR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ZI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AAT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ADNT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AGCO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AIZ', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ARCC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ARMK', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ATEN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ATO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AUDC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BV', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CCK', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SCSC', 'Errors': "'NoneType' object has no attribute 'reset_index'"}
# found dict:
# {'Symbol': 'BDC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BKH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BLBD', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BXMT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CDW', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CMRE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CPRI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CRTO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CVS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CXW', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'D', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DIS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EEFT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EFX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EMR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EPC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EQC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ESE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ETN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FLNC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FLT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'WYNN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HLT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'IPG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ITT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'KIM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'KN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LADR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LIVE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LVO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MAS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MESA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MHK', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MODG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MPAA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MSGE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MSI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NGL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NSIT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NSP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ONTO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'OSCR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PATK', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PECO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ENTG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FELE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FSP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GEO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GXO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HRI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HWM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ILPT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ISSC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'IVT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'KO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LDOS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MAR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MIR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MTLS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NMTC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NRC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NRDS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'OSUR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PAX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'POWW', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'QSR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CHH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CLBT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'TTD', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'TWLO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'TXG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'UPWK', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'WCN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'WELL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'WH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'WHG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'Z', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ZD', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AEE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AEL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ALKS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AMN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ARCH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AXTI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BFAM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BIO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BJRI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BLMN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BORR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BPMC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GVA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'POOL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'RDFN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AVNS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AWI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BKD', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BRSP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BSM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CHK', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CVI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CW', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CWH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CZR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DAN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DFIN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DRH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ELAN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EQX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ESI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ETRN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FANG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FET', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GLT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HALO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HCKT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BCO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DVA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EDIT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EPR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ESCA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ETSY', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EVBG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EVH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EVTC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FDP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FIVN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FIX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FNF', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FPI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FVRR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GEL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GKOS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GRMN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GSM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GTY', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HEES', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'IART', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'IBP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BKNG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BOOM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BWXT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CBRE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CCOI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CENX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CHE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'COMM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CTO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CVNA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CWK', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CYRX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DAIO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DAO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EFC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EIX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EME', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ENOV', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ENV', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ERIE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EXLS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FND', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PRI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'W', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'WBD', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'WOW', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'YETI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ZETA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ZEUS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ALG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BBDC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BRC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CRI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DBRG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DINO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EOG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EVRG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GTLS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GTN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NWN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SLCA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SMLP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SSP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'TBLA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'UNIT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ACAD', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BVN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CBRL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CERS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CLNE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CLOV', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CNSL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'COMP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CPNG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CRON', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CSTL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CUTR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CVEO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DEA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DOMA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ECVT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EDR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EHTH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FIGS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FLGT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FOUR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MCHX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SRE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CULP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CWT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CYTK', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DCI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DIBS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DIN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DMRC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DV', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EVLV', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EVRI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EYE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FIP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FNKO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FSS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FTDR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GDEN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GEF', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GOLF', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GSAT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GSL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GWH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HGV', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'QRTEA', 'Errors': "'NoneType' object has no attribute 'reset_index'"}
# found dict:
# {'Symbol': 'SIX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SRI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SSYS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'STER', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SUP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SYRS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'TGLS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'TRIN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'TTSH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'VERI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'VLD', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'VSCO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'VTEX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'VVX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'WHF', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HIBB', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'OFS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ONCY', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ASLE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AVAV', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BBAR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BDSX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GRND', 'Errors': "'NoneType' object has no attribute 'reset_index'"}
# found dict:
# {'Symbol': 'NINE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ONL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PMTS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'RBT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'REPX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'REVG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SMRT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SPIR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'STR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'TACT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'UNFI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'VET', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'VSEC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'YMM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'YSG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ACHR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AEYE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AKA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AKBA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ALTG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ANIP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ATER', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MTN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CTOS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EEX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FINV', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GES', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HGTY', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'KOPN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LEN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LUNA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ML', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PRCH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'S', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SES', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SGHC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SHIP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SKLZ', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'VATE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'VCSA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'WEST', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ADBE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ARCO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BRCC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BRLT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BW', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MOVE', 'Errors': "'NoneType' object has no attribute 'reset_index'"}
# found dict:
# {'Symbol': 'GME', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HUYA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NKE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ONON', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'OXSQ', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PAYS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SY', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'VNET', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ZEPP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AEVA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ATXS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BZUN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CHWY', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FTHM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'KBH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LFMD', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LIQT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MLKN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PHR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SCVL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BCLI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BRZE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BTTX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CURI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FAZE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GAN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'IDEX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'IONQ', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'IZEA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'KINS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MKTW', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NEOG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NEPT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NRXP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PLSE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PPSI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'QBTS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'RKDA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'RMTI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SHPW', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SPRO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'UGRO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ACNT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'KRTX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MDU', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MNMD', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MNTX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MTZ', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NVCR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'POST', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SWK', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'UPBD', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CIO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'FYBR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AESI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ARIS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BRBR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BRDG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LILA', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SLDP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'VTS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'WTRG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'XNCR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AGEN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AGM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ARRY', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ASRT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AFCG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NWS', 'Errors': "'NoneType' object has no attribute 'reset_index'"}
# found dict:
# {'Symbol': 'LITB', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SPWH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CAL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'DG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ALLG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SAIC', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SNT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'JILL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AGX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HOFT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HYZN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'KIRK', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'VNCE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MIND', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CGNT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'LZB', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'APOG', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'KMX', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CCL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'AOUT', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BB', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'MITK', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PSQH', 'Errors': "'NoneType' object has no attribute 'reset_index'"}
# found dict:
# {'Symbol': 'YUM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CARS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'COR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CRDF', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'GDYN', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PLTR', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ARKO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'HHH', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'STEP', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'EPM', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'KVYO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NCMI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'SRRK', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'TKO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'UPST', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'ATS', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'CART', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NVEI', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'INO', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'NVVE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PFIE', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PKST', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'PWFL', 'Errors': "'Earnings Date'"}
# found dict:
# {'Symbol': 'BETR', 'Errors': "'NoneType' object has no attribute 'reset_index'"}
#                Earnings Date  EPS Estimate  Reported EPS  Surprise(%) Symbol
# 0  2024-07-05 08:00:00-04:00           NaN           NaN          NaN   LEDS
# 1  2024-04-10 08:00:00-04:00           NaN           NaN          NaN   LEDS
# 2  2024-01-12 06:00:00-05:00           NaN           NaN          NaN   LEDS
# 3  2023-11-13 06:00:00-05:00           NaN           NaN          NaN   LEDS
# 4  2023-11-10 04:00:00-05:00           NaN           NaN          NaN   LEDS
# ..                       ...           ...           ...          ...    ...
# 7  2020-08-04 16:00:00-04:00          0.13          0.27       1.0301    MNR
# 8  2020-05-06 16:00:00-04:00          0.09         -0.77      -9.2796    MNR
# 9  2020-02-06 16:00:00-05:00          0.11          0.04      -0.6190    MNR
# 10 2019-11-25 16:00:00-05:00          0.10          0.24       1.5263    MNR
# 11 2019-08-01 16:00:00-04:00          0.10         -0.03      -1.3158    MNR
#
# [22085 rows x 5 columns]

# %%
final_df
# Out:
#                Earnings Date  EPS Estimate  Reported EPS  Surprise(%) Symbol
# 0  2024-07-05 08:00:00-04:00           NaN           NaN          NaN   LEDS
# 1  2024-04-10 08:00:00-04:00           NaN           NaN          NaN   LEDS
# 2  2024-01-12 06:00:00-05:00           NaN           NaN          NaN   LEDS
# 3  2023-11-13 06:00:00-05:00           NaN           NaN          NaN   LEDS
# 4  2023-11-10 04:00:00-05:00           NaN           NaN          NaN   LEDS
# ..                       ...           ...           ...          ...    ...
# 7  2020-08-04 16:00:00-04:00          0.13          0.27       1.0301    MNR
# 8  2020-05-06 16:00:00-04:00          0.09         -0.77      -9.2796    MNR
# 9  2020-02-06 16:00:00-05:00          0.11          0.04      -0.6190    MNR
# 10 2019-11-25 16:00:00-05:00          0.10          0.24       1.5263    MNR
# 11 2019-08-01 16:00:00-04:00          0.10         -0.03      -1.3158    MNR
#
# [22085 rows x 5 columns]

# %%
len(final_df["Symbol"].unique())
# Out:
# 1867

# %%
final_df.to_csv("eps_data.csv", index = False)

# %%
# NOT NEEDED??? 
# def reformat_eps(result_eps_df):
#     test_df = []
#     for index in range(len(result_eps_df)):
#         print(result_eps_df.loc[index,:])
#         test_df.append(result_eps_df.loc[index,'ticker'])
#     final_df = pd.concat(result_eps_df)
#     return final_df

# %%
# clean_df = reformat_eps(final_df)
# clean_df

# %% [markdown]
# # BIN

# %%
dict = {'Symbol': 'MBWM', 'Errors': "Earnings Date"}
dict
pd.DataFrame(dict, index = [0])
# Out:
#   Symbol         Errors
# 0   MBWM  Earnings Date

# %%
unique_tickers['ticker'][:5].apply(get_basic_eps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 unique_tickers['ticker'][:5].apply(get_basic_eps)
#
# NameError: name 'unique_tickers' is not defined

# %%
get_basic_eps("LEDS")
# Out:
# LEDS
# Empty DataFrame
# Columns: [Earnings Date, ticker, EPS Estimate, Reported EPS, Surprise(%)]
# Index: []

# %%
test_df = []
for index in range(len(res_df)):
    # print(index)
    # print(test_df)
    test_df.append(res_df.loc[index,'ticker'])
# Out:
# 10

# %%
final_df = pd.concat(test_df)
final_df
# Out:
#                Earnings Date  EPS Estimate  Reported EPS  Surprise(%) Symbol
# 0  2024-07-05 08:00:00-04:00           NaN           NaN          NaN   LEDS
# 1  2024-04-10 08:00:00-04:00           NaN           NaN          NaN   LEDS
# 2  2024-01-12 06:00:00-05:00           NaN           NaN          NaN   LEDS
# 3  2023-11-13 06:00:00-05:00           NaN           NaN          NaN   LEDS
# 4  2023-11-10 04:00:00-05:00           NaN           NaN          NaN   LEDS
# ..                       ...           ...           ...          ...    ...
# 7  2023-04-06 06:00:00-04:00          0.31          0.37       0.1968    RPM
# 8  2023-01-05 06:00:00-05:00          1.10          1.10      -0.0026    RPM
# 9  2022-10-05 06:00:00-04:00          1.33          1.47       0.1034    RPM
# 10 2022-07-25 06:00:00-04:00          1.44          1.42      -0.0127    RPM
# 11 2022-04-06 06:00:00-04:00          0.30          0.38       0.2667    RPM
#
# [120 rows x 5 columns]

# %%
final_df['EPS Estimate'].unique()
# Out:
# array([ nan, 0.25, 0.16, 0.45, 0.4 , 0.6 , 0.57, 0.65, 0.76, 0.72, 0.05,
#        0.13, 0.23, 0.35, 0.33, 0.47, 0.49, 0.44, 0.19, 0.1 , 0.18, 0.2 ,
#        0.09, 0.07, 0.14, 0.64, 0.68, 0.59, 0.66, 0.52, 0.63, 0.58, 2.3 ,
#        2.75, 1.64, 1.59, 1.88, 2.61, 2.21, 2.16, 2.01, 3.11, 2.17, 1.65,
#        1.27, 1.11, 2.15, 1.53, 1.18, 1.43, 1.6 , 1.2 , 1.46, 1.41, 1.08,
#        1.05, 0.99, 0.74, 0.51, 1.16, 1.31, 1.62, 1.75, 1.34, 1.78, 1.74,
#        1.22, 1.55, 1.3 , 0.31, 1.1 , 1.33, 1.44, 0.3 ])

# %%
unique_tickers_test['ticker_found'][0]['DataFound']
# Out:
# 0                               EPS Estimate  Repor...
# Name: DataFound, dtype: object

# %%
def check_ticker(row):
    """for each ticker, get earnings data"""
    results = []
    res_df = pd.DataFrame(columns =[ "Symbol","Earnings Date","EPS Estimate", "Reported EPS","Surprise(%)",'error_details'])
    error_df = pd.DataFrame(columns =["Symbol","Earnings Date","EPS Estimate", "Reported EPS","Surprise(%)",'error_details'])
    print(res_df)
    print(error_df)
    # print("SYMBOL:", row, "/******")
    try: 
        ticker_data = yf.Ticker(row)
        # print(ticker_data.info)
        eps_data  = ticker_data.get_earnings_dates(limit=12).reset_index()
        # print(type(eps_data))
        eps_data['Symbol'] = row
        eps_data['error_details'] = np.nan
        print(eps_data)
        res_df2 = pd.concat([res_df, eps_data])
    except Exception as e:
        # print(f'Error:{e}')
        # print(f"{row}, Ticker not found/available. Error: {e}")
        error_df['Symbol'] = row 
        error_df['error_details'] =  f"{row}, Ticker not found/available. Error: {e}"
        # res_df2 = pd.concat([res_df, eps_data]) res_df['Symbol']
    return res_df2
