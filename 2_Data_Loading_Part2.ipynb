# %% [markdown]
# # Package imports

# %%
import pandas as pd
import pandas_market_calendars as mcal
import numpy as np
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import yfinance as yf

# %% [markdown]
# # Stock history

# %%
events_df = pd.read_csv('data/eps_days.csv')
events_df.head(10)
# Out:
#          date exchange symbol        when  \
# 0  2023-01-03   NASDAQ   LEDS   premarket
# 1  2023-01-03   NASDAQ    SGH  postmarket
# 2  2023-01-04   NASDAQ    RGP  postmarket
# 3  2023-01-04   NASDAQ    SLP  postmarket
# 4  2023-01-05     NYSE    CAG   premarket
# 5  2023-01-05   NASDAQ   HELE   premarket
# 6  2023-01-05     NYSE    LNN   premarket
# 7  2023-01-05     NYSE     LW   premarket
# 8  2023-01-05     NYSE    MSM   premarket
# 9  2023-01-05     NYSE    RPM   premarket
#
#                                       security_name exchange_codes  \
# 0               SemiLEDS Corporation - Common Stock         NASDAQ
# 1     SMART Global Holdings, Inc. - Ordinary Shares         NASDAQ
# 2         Resources Connection, Inc. - Common Stock         NASDAQ
# 3             Simulations Plus, Inc. - Common Stock         NASDAQ
# 4                 ConAgra Brands, Inc. Common Stock           XNYS
# 5              Helen of Troy Limited - Common Stock         NASDAQ
# 6                  Lindsay Corporation Common Stock           XNYS
# 7          Lamb Weston Holdings, Inc. Common Stock            XNYS
# 8  MSC Industrial Direct Company, Inc. Common Stock           XNYS
# 9               RPM International Inc. Common Stock           XNYS
#
#             next_trading_day                    eps_day  \
# 0  2023-01-04 00:00:00+00:00        2023-01-03 00:00:00
# 1  2023-01-04 00:00:00+00:00  2023-01-04 00:00:00+00:00
# 2  2023-01-05 00:00:00+00:00  2023-01-05 00:00:00+00:00
# 3  2023-01-05 00:00:00+00:00  2023-01-05 00:00:00+00:00
# 4  2023-01-06 00:00:00+00:00        2023-01-05 00:00:00
# 5  2023-01-06 00:00:00+00:00        2023-01-05 00:00:00
# 6  2023-01-06 00:00:00+00:00        2023-01-05 00:00:00
# 7  2023-01-06 00:00:00+00:00        2023-01-05 00:00:00
# 8  2023-01-06 00:00:00+00:00        2023-01-05 00:00:00
# 9  2023-01-06 00:00:00+00:00        2023-01-05 00:00:00
#
#            prior_trading_day
# 0  2022-12-30 00:00:00+00:00
# 1  2022-12-30 00:00:00+00:00
# 2  2023-01-03 00:00:00+00:00
# 3  2023-01-03 00:00:00+00:00
# 4  2023-01-04 00:00:00+00:00
# 5  2023-01-04 00:00:00+00:00
# 6  2023-01-04 00:00:00+00:00
# 7  2023-01-04 00:00:00+00:00
# 8  2023-01-04 00:00:00+00:00
# 9  2023-01-04 00:00:00+00:00

# %%
## Cleaning date columns
events_df['next_trading_day'] = pd.to_datetime(events_df['next_trading_day'])
events_df['next_trading_day'] = events_df['next_trading_day'].dt.strftime('%Y-%m-%d')

events_df['next_trading_day'] = pd.to_datetime(events_df['next_trading_day'])


# events_df

# %%
events_df['eps_day'] = events_df['eps_day'].str.slice(0, 10)
events_df['eps_day'] = pd.to_datetime(events_df['eps_day'])
# events_df['eps_day'] = events_df['eps_day'].dt.strftime('%Y-%m-%d')
# events_df

# %%
events_df['prior_trading_day'] = pd.to_datetime(events_df['prior_trading_day'])
events_df['prior_trading_day'] = pd.to_datetime(events_df['prior_trading_day'].dt.strftime('%Y-%m-%d'))

# %%
events_df.dtypes
# Out:
# date                         object
# exchange                     object
# symbol                       object
# when                         object
# security_name                object
# exchange_codes               object
# next_trading_day     datetime64[ns]
# eps_day              datetime64[ns]
# prior_trading_day    datetime64[ns]
# dtype: object

# %%
events_df.head(15)
# Out:
#           date exchange symbol        when  \
# 0   2023-01-03   NASDAQ   LEDS   premarket
# 1   2023-01-03   NASDAQ    SGH  postmarket
# 2   2023-01-04   NASDAQ    RGP  postmarket
# 3   2023-01-04   NASDAQ    SLP  postmarket
# 4   2023-01-05     NYSE    CAG   premarket
# 5   2023-01-05   NASDAQ   HELE   premarket
# 6   2023-01-05     NYSE    LNN   premarket
# 7   2023-01-05     NYSE     LW   premarket
# 8   2023-01-05     NYSE    MSM   premarket
# 9   2023-01-05     NYSE    RPM   premarket
# 10  2023-01-05      NaN     SI   premarket
# 11  2023-01-09   NASDAQ   APLD  postmarket
# 12  2023-01-09     NYSE    AYI   premarket
# 13  2023-01-09     NYSE    AZZ  postmarket
# 14  2023-01-09   NASDAQ   PSMT  postmarket
#
#                                        security_name exchange_codes  \
# 0                SemiLEDS Corporation - Common Stock         NASDAQ
# 1      SMART Global Holdings, Inc. - Ordinary Shares         NASDAQ
# 2          Resources Connection, Inc. - Common Stock         NASDAQ
# 3              Simulations Plus, Inc. - Common Stock         NASDAQ
# 4                  ConAgra Brands, Inc. Common Stock           XNYS
# 5               Helen of Troy Limited - Common Stock         NASDAQ
# 6                   Lindsay Corporation Common Stock           XNYS
# 7           Lamb Weston Holdings, Inc. Common Stock            XNYS
# 8   MSC Industrial Direct Company, Inc. Common Stock           XNYS
# 9                RPM International Inc. Common Stock           XNYS
# 10                                               NaN            NaN
# 11        Applied Digital Corporation - Common Stock         NASDAQ
# 12                              Acuity Brands, Inc.            XNYS
# 13                                          AZZ Inc.           XNYS
# 14                   PriceSmart, Inc. - Common Stock         NASDAQ
#
#    next_trading_day    eps_day prior_trading_day
# 0        2023-01-04 2023-01-03        2022-12-30
# 1        2023-01-04 2023-01-04        2022-12-30
# 2        2023-01-05 2023-01-05        2023-01-03
# 3        2023-01-05 2023-01-05        2023-01-03
# 4        2023-01-06 2023-01-05        2023-01-04
# 5        2023-01-06 2023-01-05        2023-01-04
# 6        2023-01-06 2023-01-05        2023-01-04
# 7        2023-01-06 2023-01-05        2023-01-04
# 8        2023-01-06 2023-01-05        2023-01-04
# 9        2023-01-06 2023-01-05        2023-01-04
# 10              NaT 2023-01-05               NaT
# 11       2023-01-10 2023-01-10        2023-01-06
# 12       2023-01-10 2023-01-09        2023-01-06
# 13       2023-01-10 2023-01-10        2023-01-06
# 14       2023-01-10 2023-01-10        2023-01-06

# %%
events_df.rename(columns={'eps_day': 'after_eps_date'}, inplace = True)

# %%
events_df
# Out:
#             date exchange symbol        when  \
# 0     2023-01-03   NASDAQ   LEDS   premarket
# 1     2023-01-03   NASDAQ    SGH  postmarket
# 2     2023-01-04   NASDAQ    RGP  postmarket
# 3     2023-01-04   NASDAQ    SLP  postmarket
# 4     2023-01-05     NYSE    CAG   premarket
# ...          ...      ...    ...         ...
# 8781  2023-12-21     NYSE    KMX   premarket
# 8782  2023-12-21   NASDAQ   LMNR  postmarket
# 8783  2023-12-21     NYSE    NKE   premarket
# 8784  2023-12-21   NASDAQ   PAYX   premarket
# 8785  2023-12-31     NYSE   YUMC   premarket
#
#                                       security_name exchange_codes  \
# 0               SemiLEDS Corporation - Common Stock         NASDAQ
# 1     SMART Global Holdings, Inc. - Ordinary Shares         NASDAQ
# 2         Resources Connection, Inc. - Common Stock         NASDAQ
# 3             Simulations Plus, Inc. - Common Stock         NASDAQ
# 4                 ConAgra Brands, Inc. Common Stock           XNYS
# ...                                             ...            ...
# 8781                                     CarMax Inc           XNYS
# 8782                    Limoneira Co - Common Stock         NASDAQ
# 8783                        Nike, Inc. Common Stock           XNYS
# 8784                   Paychex, Inc. - Common Stock         NASDAQ
# 8785          Yum China Holdings, Inc. Common Stock           XNYS
#
#      next_trading_day after_eps_date prior_trading_day
# 0          2023-01-04     2023-01-03        2022-12-30
# 1          2023-01-04     2023-01-04        2022-12-30
# 2          2023-01-05     2023-01-05        2023-01-03
# 3          2023-01-05     2023-01-05        2023-01-03
# 4          2023-01-06     2023-01-05        2023-01-04
# ...               ...            ...               ...
# 8781       2023-12-22     2023-12-21        2023-12-20
# 8782       2023-12-22     2023-12-22        2023-12-20
# 8783       2023-12-22     2023-12-21        2023-12-20
# 8784       2023-12-22     2023-12-21        2023-12-20
# 8785       2024-01-03     2023-12-31        2023-12-28
#
# [8786 rows x 9 columns]

# %%
# Replace values in prior_trading day based on condition in "when". 
## If when == Premarket then prior trading date remains, if when == postmarket then prior trading date update to value in the date column
events_df.loc[events_df['when'] == 'postmarket', 'prior_trading_day'] = events_df['date']

events_df.head(15)
# Out:
#           date exchange symbol        when  \
# 0   2023-01-03   NASDAQ   LEDS   premarket
# 1   2023-01-03   NASDAQ    SGH  postmarket
# 2   2023-01-04   NASDAQ    RGP  postmarket
# 3   2023-01-04   NASDAQ    SLP  postmarket
# 4   2023-01-05     NYSE    CAG   premarket
# 5   2023-01-05   NASDAQ   HELE   premarket
# 6   2023-01-05     NYSE    LNN   premarket
# 7   2023-01-05     NYSE     LW   premarket
# 8   2023-01-05     NYSE    MSM   premarket
# 9   2023-01-05     NYSE    RPM   premarket
# 10  2023-01-05      NaN     SI   premarket
# 11  2023-01-09   NASDAQ   APLD  postmarket
# 12  2023-01-09     NYSE    AYI   premarket
# 13  2023-01-09     NYSE    AZZ  postmarket
# 14  2023-01-09   NASDAQ   PSMT  postmarket
#
#                                        security_name exchange_codes  \
# 0                SemiLEDS Corporation - Common Stock         NASDAQ
# 1      SMART Global Holdings, Inc. - Ordinary Shares         NASDAQ
# 2          Resources Connection, Inc. - Common Stock         NASDAQ
# 3              Simulations Plus, Inc. - Common Stock         NASDAQ
# 4                  ConAgra Brands, Inc. Common Stock           XNYS
# 5               Helen of Troy Limited - Common Stock         NASDAQ
# 6                   Lindsay Corporation Common Stock           XNYS
# 7           Lamb Weston Holdings, Inc. Common Stock            XNYS
# 8   MSC Industrial Direct Company, Inc. Common Stock           XNYS
# 9                RPM International Inc. Common Stock           XNYS
# 10                                               NaN            NaN
# 11        Applied Digital Corporation - Common Stock         NASDAQ
# 12                              Acuity Brands, Inc.            XNYS
# 13                                          AZZ Inc.           XNYS
# 14                   PriceSmart, Inc. - Common Stock         NASDAQ
#
#    next_trading_day after_eps_date prior_trading_day
# 0        2023-01-04     2023-01-03        2022-12-30
# 1        2023-01-04     2023-01-04        2023-01-03
# 2        2023-01-05     2023-01-05        2023-01-04
# 3        2023-01-05     2023-01-05        2023-01-04
# 4        2023-01-06     2023-01-05        2023-01-04
# 5        2023-01-06     2023-01-05        2023-01-04
# 6        2023-01-06     2023-01-05        2023-01-04
# 7        2023-01-06     2023-01-05        2023-01-04
# 8        2023-01-06     2023-01-05        2023-01-04
# 9        2023-01-06     2023-01-05        2023-01-04
# 10              NaT     2023-01-05               NaT
# 11       2023-01-10     2023-01-10        2023-01-09
# 12       2023-01-10     2023-01-09        2023-01-06
# 13       2023-01-10     2023-01-10        2023-01-09
# 14       2023-01-10     2023-01-10        2023-01-09

# %%
stock_result = pd.DataFrame()
def stock_history(row):
    ''' get stock prices for the days between before and after for each stock'''
    ticker = row['symbol']
    # print(ticker)
    data = yf.Ticker(ticker)
    result = data.history(start=row['prior_trading_day'], end = row['after_eps_date']+pd.Timedelta(days=1))
    result['symbol'] = ticker
    result.reset_index(drop=False, inplace=True)
    result.set_index('symbol', inplace =True)
    # result['Date'] = pd.to_datetime(result['Date'])
    result['Date'] = pd.to_datetime(result['Date']).dt.strftime('%Y-%m-%d')
    return result

# %%
# QA testing one row
# pct_test = stock_history(events_df.iloc[1,:])

# pct_test

# full DF
prices = events_df.apply(stock_history, axis=1)
prices
# Out:
# SI: No timezone found, symbol may be delisted
# BBBY: No timezone found, symbol may be delisted
# FRC: No timezone found, symbol may be delisted
# SIVB: No timezone found, symbol may be delisted
# CR: Data doesn't exist for startDate = 1674450000, endDate = 1674622800
# NXGN: No timezone found, symbol may be delisted
# OBNK: No timezone found, symbol may be delisted
# XM: No timezone found, symbol may be delisted
# AQUA: No timezone found, symbol may be delisted
# NATI: No timezone found, symbol may be delisted
# ABC: No timezone found, symbol may be delisted
# GHL: No timezone found, symbol may be delisted
# LCI: No timezone found, symbol may be delisted
# MMP: No timezone found, symbol may be delisted
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 7
#       1 # QA testing one row
#       2 # pct_test = stock_history(events_df.iloc[1,:])
#       3
#       4 # pct_test
#       5
#       6 # full DF
# ----> 7 prices = events_df.apply(stock_history, axis=1)
#       8 prices
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lhl_midterm_env/lib/python3.9/site-packages/pandas/core/frame.py:10034, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10022 from pandas.core.apply import frame_apply
#   10024 op = frame_apply(
#   10025     self,
#   10026     func=func,
#    (...)
#   10032     kwargs=kwargs,
#   10033 )
# > 10034 return op.apply().__finalize__(self, method="apply")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lhl_midterm_env/lib/python3.9/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lhl_midterm_env/lib/python3.9/site-packages/pandas/core/apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lhl_midterm_env/lib/python3.9/site-packages/pandas/core/apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# Cell In[11], line 7, in stock_history(row)
#       5 # print(ticker)
#       6 data = yf.Ticker(ticker)
# ----> 7 result = data.history(start=row['prior_trading_day'], end = row['after_eps_date']+pd.Timedelta(days=1))
#       8 result['symbol'] = ticker
#       9 result.reset_index(drop=False, inplace=True)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lhl_midterm_env/lib/python3.9/site-packages/yfinance/utils.py:103, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     100 logger.debug(f'Entering {func.__name__}()')
#     102 with IndentationContext():
# --> 103     result = func(*args, **kwargs)
#     105 logger.debug(f'Exiting {func.__name__}()')
#     106 return result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lhl_midterm_env/lib/python3.9/site-packages/yfinance/base.py:77, in TickerBase.history(self, *args, **kwargs)
#      75 @utils.log_indent_decorator
#      76 def history(self, *args, **kwargs) -> pd.DataFrame:
# ---> 77     return self._lazy_load_price_history().history(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lhl_midterm_env/lib/python3.9/site-packages/yfinance/utils.py:103, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     100 logger.debug(f'Entering {func.__name__}()')
#     102 with IndentationContext():
# --> 103     result = func(*args, **kwargs)
#     105 logger.debug(f'Exiting {func.__name__}()')
#     106 return result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lhl_midterm_env/lib/python3.9/site-packages/yfinance/scrapers/history.py:104, in PriceHistory.history(self, period, interval, start, end, prepost, actions, auto_adjust, back_adjust, repair, keepna, proxy, rounding, timeout, raise_errors)
#     102             start = int(max_start_datetime.timestamp())
#     103     else:
# --> 104         start = utils._parse_user_dt(start, tz)
#     105     params = {"period1": start, "period2": end}
#     106 else:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lhl_midterm_env/lib/python3.9/site-packages/yfinance/utils.py:417, in _parse_user_dt(dt, exchange_tz)
#     414         dt = _datetime.datetime.combine(dt, _datetime.time(0))
#     415     if isinstance(dt, _datetime.datetime) and dt.tzinfo is None:
#     416         # Assume user is referring to exchange's timezone
# --> 417         dt = _tz.timezone(exchange_tz).localize(dt)
#     418     dt = int(dt.timestamp())
#     419 return dt
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lhl_midterm_env/lib/python3.9/site-packages/pytz/tzinfo.py:331, in DstTzInfo.localize(self, dt, is_dst)
#     329 inf = self._transition_info[idx]
#     330 tzinfo = self._tzinfos[inf]
# --> 331 loc_dt = tzinfo.normalize(dt.replace(tzinfo=tzinfo))
#     332 if loc_dt.replace(tzinfo=None) == dt:
#     333     possible_loc_dt.add(loc_dt)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lhl_midterm_env/lib/python3.9/site-packages/pytz/tzinfo.py:252, in DstTzInfo.normalize(self, dt)
#     207 '''Correct the timezone information on the given datetime
#     208
#     209 If date arithmetic crosses DST boundaries, the tzinfo
#    (...)
#     249 '2011-05-06 20:02:03 CEST (+0200)'
#     250 '''
#     251 if dt.tzinfo is None:
# --> 252     raise ValueError('Naive time - no tzinfo set')
#     254 # Convert dt in localtime to UTC
#     255 offset = dt.tzinfo._utcoffset
#
# ValueError: Naive time - no tzinfo set

# %%
pct_test.dtypes

# %%
pct_test = pct_test[['Open', 'High','Low','Close']].pct_change(axis=0).dropna()

# %%
pct_test

# %%
pct_test = pct_test[['Open', 'High','Low','Close']].pct_change(axis=0).dropna()

# %% [markdown]
# ## Bin

# %%
ticker_list = events_df['symbol'].tolist()
ticker_list = set([ticker.lower() for ticker in ticker_list])
print(len(ticker_list))
ticker_list

# %%
print(events_df.loc[0,'after_eps_date'])
print(events_df.loc[0,'after_eps_date']+pd.Timedelta(days=1))

# %%
events_df['after_eps_date'] = np.nan
events_df['before_eps_date'] = np.nan

# %%
events_df

# %%
### next trading day is after eps date for all values where WHEN = Postmarket

# Define a function to conditionally replace values
def get_after_date(row):
    if row['when'] == 'postmarket':
        return row['next_trading_day']
    elif row['when'] == 'premarket':
        return row['date']
    else:
        return row['next_trading_day']

# Apply the function to create a new column 'D' with the replaced values
events_df['after_eps_date'] = events_df.apply(get_after_date, axis=1)

# %%
events_df

# %%
# Define a function to conditionally replace values
def get_before_date(row):
    if row['when'] == 'postmarket':
        return row['date']
    elif row['when'] == 'premarket':
        return row['prior_trading_day']
    else:
        return row['next_trading_day']

# Apply the function to create a new column 'D' with the replaced values
events_df['before_eps_date'] = events_df.apply(get_before_date, axis=1)

# %%
events_df.dtypes

# %%
events_df['after_eps_date'] = pd.to_datetime(events_df['after_eps_date'])
events_df['before_eps_date'] = pd.to_datetime(events_df['before_eps_date'])

# %%
events_df.head(15)

# %%
events_df.dtypes
